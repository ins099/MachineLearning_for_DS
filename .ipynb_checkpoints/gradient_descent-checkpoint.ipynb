# %%
import numpy as np
import math

# %%
# def gradient_descent(x,y,it=1000, lr = 0.01):
#     m_carr = b_carr = 0
#     iterations = it
#     n = len(x)
#     learning_R = lr
#     for i in range(iterations):
#         y_predict = m_carr * x + b_carr
#         cost = (1/n) * sum([value**2 for value in (y-y_predict)])
#         md = -(2/n)*sum(x*(y-y_predict))
#         bd = -(2/n)*sum(y-y_predict)
        
#         m_carr = m_carr - learning_R* md
#         b_carr = b_carr - learning_R* bd
#         print(f"m  {m_carr}, b  {b_carr},  cost  {cost},  iteration{i}")



# x=np.array([1,2,3,4,5])
# y=np.array([5,7,9,11,13])

# # gradient_descent(x,y)

# %% [markdown]
# # Gradient Descent Exercise

# %%
import pandas as pd

# %%
df = pd.read_csv('testscores.csv')
a = np.array(df.math)
b = np.array(df.cs)
b
# Out:
# array([98, 68, 81, 80, 83, 52, 66, 30, 68, 73], dtype=int64)

# %%
# def gradient_descent(x,y):
#     m_curr = 0
#     b_curr = 0
#     iterations = 1000000
#     n = len(x)
#     learning_rate = 0.0002

#     cost_previous = 0

#     for i in range(iterations):
#         y_predicted = m_curr * x + b_curr
#         cost = (1/n)*sum([value**2 for value in (y-y_predicted)])
#         md = -(2/n)*sum(x*(y-y_predicted))
#         bd = -(2/n)*sum(y-y_predicted)
#         m_curr = m_curr - learning_rate * md
#         b_curr = b_curr - learning_rate * bd
#         if math.isclose(cost, cost_previous, rel_tol=1e-20):
#           print("it breaked")
#           break
#         cost_previous = cost
#         print ("m {}, b {}, cost {}, iteration {}".format(m_curr,b_curr,cost, i))

#     return m_curr, b_curr

# %%
# Out:
# m  1.9783600000000003, b  0.027960000000000002,  cost  5199.1,  iteration0
# m  0.20975041279999962, b  0.0030470367999999894,  cost  4161.482445460163,  iteration1
# m  1.7908456142986242, b  0.025401286955264,  cost  3332.2237319269248,  iteration2
# m  0.37738163667530467, b  0.005499731626422651,  cost  2669.4843523161976,  iteration3
# m  1.6409848166378898, b  0.023373894401807944,  cost  2139.826383775145,  iteration4
# m  0.5113514173939655, b  0.0074774305434828076,  cost  1716.5264071567592,  iteration5
# m  1.5212165764726306, b  0.021771129698498662,  cost  1378.2272007804495,  iteration6
# m  0.6184191426785134, b  0.009075514323270572,  cost  1107.8601808918404,  iteration7
# m  1.4254981563597626, b  0.020507724625171385,  cost  891.7842215178443,  iteration8
# m  0.7039868810749315, b  0.010370210797388455,  cost  719.0974036421305,  iteration9
# m  1.3490002310389348, b  0.01951553325074733,  cost  581.0869686205,  iteration10
# ...
